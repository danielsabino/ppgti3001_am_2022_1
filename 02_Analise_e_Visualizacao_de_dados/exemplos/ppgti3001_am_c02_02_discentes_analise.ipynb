# %%
import pandas as pd
import matplotlib.pyplot as plt
import gdown
plt.style.use('ggplot')

# %%
url = 'https://drive.google.com/file/d/1dHJf2Sj9GuYm9VWaA1icBhd2F6i9PIcG/view?usp=sharing'
output = 'discentes.csv'
gdown.download(url=url, output=output, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dHJf2Sj9GuYm9VWaA1icBhd2F6i9PIcG
# To: /content/discentes.csv
# 100%|██████████| 69.5M/69.5M [00:00<00:00, 157MB/s]
# 'discentes.csv'

# %%
data = pd.read_csv('discentes.csv', sep=';', parse_dates=True)

# %%
data.head()
# Out:
#                         id_discente sexo  ano_nascimento           raca  \
# 0  0e356f33d9f25c70bd7b98ef1bd1ecd4    M          1943.0  Não Informado
# 1  a3f7753971d7ca9c1648616b1f7e4c48    M          1949.0  Não Informado
# 2  d29e0a56e3cc973750e2d2cbabedc449    F          1947.0  Não Informado
# 3  d4f89fe5c6dd43692b3c1fc4ce324fd5    M          1949.0  Não Informado
# 4  e2f244371122aea4140427ada6f391b4    M          1944.0  Não Informado
#
#          estado_origem cidade_origem               estado municipio    bairro  \
# 0  Rio Grande do Norte         NATAL  Rio Grande do Norte     NATAL  NEOPOLIS
# 1       Rio de Janeiro           NaN                  NaN       NaN       NaN
# 2                  NaN           NaN                  NaN       NaN       NaN
# 3  Rio Grande do Norte           NaN                  NaN       NaN       NaN
# 4  Rio Grande do Norte         NATAL  Rio Grande do Norte     NATAL   ALECRIM
#
#   nivel_ensino forma_ingresso  ano_ingresso  periodo_ingresso cotista
# 0    GRADUAÇÃO     VESTIBULAR          1969               1.0       f
# 1    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 2    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 3    GRADUAÇÃO     VESTIBULAR          1970               1.0       f
# 4    GRADUAÇÃO     VESTIBULAR          1970               1.0       f

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401711 entries, 0 to 401710
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_discente       401711 non-null  object
#  1   sexo              401711 non-null  object
#  2   ano_nascimento    400969 non-null  float64
#  3   raca              401591 non-null  object
#  4   estado_origem     378367 non-null  object
#  5   cidade_origem     360549 non-null  object
#  6   estado            360160 non-null  object
#  7   municipio         360160 non-null  object
#  8   bairro            339771 non-null  object
#  9   nivel_ensino      401711 non-null  object
#  10  forma_ingresso    392619 non-null  object
#  11  ano_ingresso      401711 non-null  int64
#  12  periodo_ingresso  401177 non-null  float64
#  13  cotista           401711 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 42.9+ MB

# %%
data.describe()
# Out:
#        ano_nascimento   ano_ingresso  periodo_ingresso
# count   400969.000000  401711.000000     401177.000000
# mean      1966.008243    2008.808176          1.422960
# std        172.778685      10.442243          0.508853
# min          1.000000     209.000000          0.000000
# 25%       1975.000000    2005.000000          1.000000
# 50%       1986.000000    2013.000000          1.000000
# 75%       1994.000000    2015.000000          2.000000
# max       2071.000000    2020.000000          3.000000

# %%
data[['ano_ingresso','ano_nascimento']].plot(kind='box')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
data = data[(data['ano_ingresso'] > 1950) & (data['ano_ingresso'] < 2020)]
data = data[(data['ano_nascimento'] > 1850) & (data['ano_nascimento'] < 2005)]
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396674 entries, 0 to 401710
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_discente       396674 non-null  object
#  1   sexo              396674 non-null  object
#  2   ano_nascimento    396674 non-null  float64
#  3   raca              396642 non-null  object
#  4   estado_origem     373699 non-null  object
#  5   cidade_origem     355906 non-null  object
#  6   estado            355498 non-null  object
#  7   municipio         355498 non-null  object
#  8   bairro            335155 non-null  object
#  9   nivel_ensino      396674 non-null  object
#  10  forma_ingresso    388039 non-null  object
#  11  ano_ingresso      396674 non-null  int64
#  12  periodo_ingresso  396518 non-null  float64
#  13  cotista           396674 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 45.4+ MB
#        ano_nascimento   ano_ingresso  periodo_ingresso
# count   396674.000000  396674.000000     396518.000000
# mean      1981.715071    2008.764401          1.421923
# std         17.649774       9.677386          0.508411
# min       1873.000000    1969.000000          0.000000
# 25%       1976.000000    2005.000000          1.000000
# 50%       1986.000000    2013.000000          1.000000
# 75%       1994.000000    2015.000000          2.000000
# max       2004.000000    2019.000000          3.000000

# %%
data[['ano_ingresso','ano_nascimento']].plot(kind='box')
plt.show()

# %%
plt.violinplot([data['ano_ingresso'].values,data['ano_nascimento'].values])
plt.show()

# %%
data[['ano_ingresso','ano_nascimento']].plot(kind='hist', bins=30, alpha=0.8)
plt.show()

# %%
data[['ano_ingresso','ano_nascimento']].plot(kind='hist', bins=30, range=(1900,2019), cumulative=True, alpha=0.3)
plt.xlabel('Ano de Nascimento')
plt.show()

# %%
data['raca'].describe()
# Out:
# count            396642
# unique                7
# top       Não Informado
# freq             163488
# Name: raca, dtype: object

# %%
data['raca'].unique()
# Out:
# array(['Não Informado', 'Branco', 'Pardo', 'Negro', 'Indígeno',
#        'Amarelo (de origem oriental)', nan, 'Remanescente de quilombo'],
#       dtype=object)

# %%
print(data['raca'].value_counts())
data['raca'].value_counts().plot.bar()
plt.show()
# Out:
# Não Informado                   163488
# Pardo                           113159
# Branco                          103778
# Negro                            14793
# Indígeno                           715
# Amarelo (de origem oriental)       626
# Remanescente de quilombo            83
# Name: raca, dtype: int64

# %%
a = data['estado_origem'].value_counts()
print(data['estado_origem'].value_counts())
data['estado_origem'].value_counts().plot.bar()
plt.show()
# Out:
# Rio Grande do Norte    299718
# Paraíba                 11296
# Rio de Janeiro           9763
# São Paulo                9260
# Pernambuco               8393
# Ceará                    7000
# Bahia                    2828
# Ignorado/exterior        2523
# Minas Gerais             2444
# Não Informado            2411
# Pará                     2195
# Distrito Federal         2149
# Rio Grande do Sul        1863
# Piauí                    1752
# Paraná                   1192
# Maranhão                 1124
# Alagoas                  1066
# Goiás                    1034
# Amazonas                  967
# Sergipe                   764
# Santa Catarina            587
# Mato Grosso do Sul        574
# Mato Grosso               565
# Acre                      526
# Rondônia                  510
# Espírito Santo            481
# Amapá                     301
# Roraima                   230
# Tocantins                 183
# Name: estado_origem, dtype: int64

# %%
data.plot.scatter(x='ano_nascimento',y='ano_ingresso')
plt.show()
